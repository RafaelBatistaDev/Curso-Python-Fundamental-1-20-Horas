# %%
print(7)
print(4+3)
print(2+100+0+1+1-5)
print(3*3)
print(12/4)
print(2**3)
print(10%3)
print(10//3)
print((2+3)*4)
print(2+3*4)
print(7>4)
print(3==5)
print(3!=5)
print(3<5 and 7>4)
print(3<5 or 7<4)
print(not(3<5))
print("Hello, World!")
print("Hello" + " " + "World")
print("Hello " * 3)
print("Hello"[0])
print("Hello"[1])
print("Hello"[2])

print("Hello"[3])
print("Hello"[4])
print(len("Hello"))

print(7+6/2)


print((7+6)/2)
print(-3**2)

print('tele'+'fone')
print('10'+'20'+'30')
print('Ae'*4)

print(4*2)
print(4*2.5)
print(1+2)
print(1.0+2)
print(4/2)

print(10+3*2)
print(2*-3**2)
print(8%2)
# Out:
# 7
# 7
# 99
# 9
# 3.0
# 8
# 1
# 3
# 20
# 14
# True
# False
# True
# True
# True
# False
# Hello, World!
# Hello World
# Hello Hello Hello
# H
# e
# l
# l
# o
# 5
# 10.0
# 6.5
# -9
# telefone
# 102030
# AeAeAeAe
# 8
# 10.0
# 3
# 3.0
# 2.0
# 16
# -18
# 0
