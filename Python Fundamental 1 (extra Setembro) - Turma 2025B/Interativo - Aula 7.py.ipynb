# %%
nome=input("Rafael")
print("Tenha um Bom dia", {nome}, "e não esqueça de praticar!")

nome=input("Rafael")
print(f'tenha um Bom dia, {nome}, e não esqueça de praticar!')
# Out:
# Tenha um Bom dia {''} e não esqueça de praticar!
# tenha um Bom dia, , e não esqueça de praticar!

# %%
nome="Rafael"
print("Tenha um Bom dia", {nome}, "e não esqueça de praticar!")

nome=input("Rafael")
print(f'tenha um Bom dia, {nome}, e não esqueça de praticar!')
# Out:
# Tenha um Bom dia {'Rafael'} e não esqueça de praticar!
# tenha um Bom dia, , e não esqueça de praticar!
# tenha um Bom dia, , e não esqueça de praticar!

# %%
nome="Rafael"
print("Tenha um Bom dia", nome, "e não esqueça de praticar!")

nome=input("Rafael")
print(f'tenha um Bom dia, {nome}, e não esqueça de praticar!')
# Out:
# Tenha um Bom dia Rafael e não esqueça de praticar!
# tenha um Bom dia, , e não esqueça de praticar!

# %%
nome="Rafael"
print("Tenha um Bom dia", nome, "e não esqueça de praticar!")

nome=input("Rafael")
print(f'tenha um Bom dia, {nome}, e não esqueça de praticar!')

x=10
print(f"o dobro da valor armazenado na variavel é {x*2}")
# Out:
# Tenha um Bom dia Rafael e não esqueça de praticar!
# tenha um Bom dia, ], e não esqueça de praticar!
# o dobro da valor armazenado na variavel é 20

# %%
nome="Rafael"
print("Tenha um Bom dia", nome, "e não esqueça de praticar!")

nome=input("Rafael")
print(f'tenha um Bom dia, {nome}, e não esqueça de praticar!')

x=10
print(f"o dobro da valor armazenado na variavel é {x*2}")
print(f"o dobro da valor armazenado na variavel é {x*2}")
# Out:
# Tenha um Bom dia Rafael e não esqueça de praticar!
# tenha um Bom dia, , e não esqueça de praticar!
# o dobro da valor armazenado na variavel é 20
# o dobro da valor armazenado na variavel é 20
# tenha um Bom dia, , e não esqueça de praticar!
# o dobro da valor armazenado na variavel é 20
# o dobro da valor armazenado na variavel é 20

# %%
nome="Rafael"
print("Tenha um Bom dia", nome, "e não esqueça de praticar!")

nome=input("Rafael")
print(f'tenha um Bom dia, {nome}, e não esqueça de praticar!')

x=10
print(f"o dobro da valor armazenado na variavel é {x*2}")
print("o dobro da valor armazenado na variavel é {x*2}")
# Out:
# Tenha um Bom dia Rafael e não esqueça de praticar!
# tenha um Bom dia, , e não esqueça de praticar!
# o dobro da valor armazenado na variavel é 20
# o dobro da valor armazenado na variavel é {x*2}
