# %% [markdown]
# Conectado a .venv (Python 3.12.3)

# %%
print(12345)
print(-22)
print(0)
print(+3)

print(-4.1)
print(3.141516195535)
print(+2.0)
print(2.)

print("Testando literais do tipo string")
print('Testando literais do tipo string')
print("""Testando literais do tipo string""")
print('''Testando literais do tipo string''')
print("  0  0  ")
print('  -  ')
print("""  |  """)
print('''  ^  ''')
print("   #   ")
print('   *   ')
print("""   @   """)
print('   $   ')
print("--------")
print('Ele disse: "Olá, tudo bem?"')
print("Ele disse: \"Olá, tudo bem?\"")
print("tOlá!\nPerceba que eu pulei uma linha.")



def default_message():
    print("Yan, Maria Clara, Phelipe vcs são o motivo pŕa eu começar a dominar o Python")
    print("A vida se toran melhor quando agente quer.")
    print("Deus é Maior")
##### by Recife Crypto #####
# Out:
# 12345
# -22
# 0
# 3
# -4.1
# 3.141516195535
# 2.0
# 2.0
# Testando literais do tipo string
# Testando literais do tipo string
# Testando literais do tipo string
# Testando literais do tipo string
#   0  0
#   -
#   |
#   ^
#    #
#    *
#    @
#    $
# --------
# Ele disse: "Olá, tudo bem?"
# Ele disse: "Olá, tudo bem?"
# tOlá!
# Perceba que eu pulei uma linha.
