# %%
if 10<20:
    print("estas linhas serão executadas somente...")
    print("se a condição depois do if resultar em true")
# Out:
# estas linhas serão executadas somente...
# se a condição depois do if resultar em true

# %%
if 40<20:
    print("estas linhas serão executadas somente...")
    print("se a condição depois do if resultar em true")

# %%
if 40<60:
    print("estas linhas serão executadas somente...")
    print("se a condição depois do if resultar em true")
# Out:
# estas linhas serão executadas somente...
# se a condição depois do if resultar em true

# %%
if 40==60:
    print("estas linhas serão executadas somente...")
    print("se a condição depois do if resultar em true")

# %%
if 40=40:
    print("estas linhas serão executadas somente...")
    print("se a condição depois do if resultar em true")
# Out:
#   Cell In[5], line 1
#     if 40=40:
#        ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
if 40==40:
    print("estas linhas serão executadas somente...")
    print("se a condição depois do if resultar em true")
# Out:
# estas linhas serão executadas somente...
# se a condição depois do if resultar em true
