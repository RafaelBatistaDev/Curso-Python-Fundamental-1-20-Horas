# %%
resultado=(5*20)
print(resultado)
x="lalala"
print(x)
# Out:
# 100
# lalala

# %%
resultado=(5*20)
print(resultado)
x="lalala"
print(x)
#Fodasse
# Out:
# 100
# lalala

# %%
resultado=(5*20)
print(resultado)
x="lalala"
print(x)
#Fodasse
# Out:
# 100
# lalala
