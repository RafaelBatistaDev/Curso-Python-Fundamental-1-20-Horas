# %%
peso=89.2
print(peso)
peso= 89.2
print(peso)
peso=89.2
print(peso+10)
nome="Gabriel"
print(nome+"rafael")
nome="Gabriel"
nome="Nome+Rafael"
print(nome+"Rafael")
nome="Gabriel"
nome=nome+"Rafael"
print(nome)
nome="Gabriel"
nome="Gabriel"+"Rafael"
print(nome)

A,B=5,10
print(B)
# Out:
# 89.2
# 89.2
# 99.2
# Gabrielrafael
# Nome+RafaelRafael
# GabrielRafael
# GabrielRafael
# 10
