# %%
x=40
if x <30 and x>0:
    print("o Resultado da expressão foi verdadeiro")
    
    x = 10
if x < 20 and x > 15:
     print('O resultado da expressão foi verdadeiro')

# %%
x=40
if x <30 and x>0:
    print("o Resultado da expressão foi verdadeiro")
    
    x = 10
if x < 70 and x > 15:
     print('O resultado da expressão foi verdadeiro')
