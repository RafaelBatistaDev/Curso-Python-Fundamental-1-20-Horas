# %%
minhavar="2025"
print(type(minhavar))
minhavar=2024
print(type(minhavar))
minhavar=20.24
print(type(minhavar))
minhavar=True
print(type(minhavar))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
