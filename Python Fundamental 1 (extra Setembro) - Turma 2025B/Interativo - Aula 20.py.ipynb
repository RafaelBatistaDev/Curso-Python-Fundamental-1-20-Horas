# %%
x = 10
if x < 20 or x > 15:
      print('O resultado da expressão foi verdadeiro')
if x < 20 or x > 15:
      print('O resultado da expressão foi verdadeiro')
# Out:
# O resultado da expressão foi verdadeiro
# O resultado da expressão foi verdadeiro

# %%
x = 10
if x < 20 or x > 15:
      print('O resultado da expressão foi verdadeiro')
if x < 40 or x > 15:
      print('O resultado da expressão foi verdadeiro')
# Out:
# O resultado da expressão foi verdadeiro
# O resultado da expressão foi verdadeiro

# %%
x = 10
if x < 20 or x > 15:
      print('O resultado da expressão foi verdadeiro')
if x < 40 or x > 45:
      print('O resultado da expressão foi verdadeiro')
# Out:
# O resultado da expressão foi verdadeiro
# O resultado da expressão foi verdadeiro

# %%
x = 80
if x < 220 or x > 15:
      print('O resultado da expressão foi verdadeiro')
if x < 40 or x > 45:
      print('O resultado da expressão foi verdadeiro')
# Out:
# O resultado da expressão foi verdadeiro
# O resultado da expressão foi verdadeiro
