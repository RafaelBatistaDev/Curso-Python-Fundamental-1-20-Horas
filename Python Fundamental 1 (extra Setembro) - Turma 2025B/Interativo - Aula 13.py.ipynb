# %%
ano=1986
print(ano>1980)
print(2000<ano)
faztempo=ano<1900
print(faztempo)

# %%
ano=1986
print(ano>1980)
# Out:
# True

# %%
ano=1986
print(ano>1980)

print(2000<ano)
faztempo=ano<1900
print(faztempo)
# Out:
# True
# False
# False

# %%
ano=1886
print(ano>1980)
print(2000<ano)
faztempo=ano<1900
print(faztempo)
# Out:
# False
# False
# True

# %%
ano=1886
print(ano>1980)
print(2000<ano)
faztempo=ano<1900
print(faztempo)
# Out:
# False
# False
# True
