# %%
valor=float(input("856"))
if valor < 0:
    print("Onúmero que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("856"))
if valor > 0:
    print("Onúmero que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("856"))
if valor > 54690:
    print("Onúmero que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("856"))
if valor > 54:
    print("Onúmero que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("-856"))
if valor > 0:
    print("O número que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("0"))
if valor > 0:
    print("O número que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input"0")
if valor > 0:
    print("O número que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input"50")
if valor > 0:
    print("O número que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input"50")
if valor > 100:
    print("O número que vc digitou é negativo")
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input"50")
if valor > 100:
    print("O número que vc digitou é negativo")
else:
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("50"))
if valor > 100:
    print("O número que vc digitou é negativo")
else:
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("50"))
if valor > 0:
    print("O número que vc digitou é negativo")
else:
    print("e eu sei disso pois ele é menor que zero")

# %%
print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("50"))
if valor > 0:
    print("O número que vc digitou é negativo")
else:
    print("e eu sei disso pois ele é menor que zero")

# %%
valor=float(input("50"))
if valor > 0:
    print("O número que vc digitou é negativo")
else:
    print("e eu sei disso pois ele é menor que zero")
