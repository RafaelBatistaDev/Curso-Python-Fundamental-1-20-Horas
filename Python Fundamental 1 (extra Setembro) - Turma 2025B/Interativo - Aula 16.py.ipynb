# %%
valor = float(input(252))
if valor< 0:
    #parte que executa com condição True
    print("o número que você digitou é negativo")
    print("e eu sei disso pois é menor que zero")
else:
    #parte que executa com condição False
    print("O número que você digitou é positivo")
    print("ou é igual a zero, não tenho certeza")
    print("Fim  do programa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 valor = float(input(252))
#       2 if valor< 0:
#       3     #parte que executa com condição True
#       4     print("o número que você digitou é negativo")
#
# ValueError: could not convert string to float: ''

# %%
valor = float(input(-252))
if valor< 0:
    #parte que executa com condição True
    print("o número que você digitou é negativo")
    print("e eu sei disso pois é menor que zero")
else:
    #parte que executa com condição False
    print("O número que você digitou é positivo")
    print("ou é igual a zero, não tenho certeza")
    print("Fim  do programa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 valor = float(input(-252))
#       2 if valor< 0:
#       3     #parte que executa com condição True
#       4     print("o número que você digitou é negativo")
#
# ValueError: could not convert string to float: ''

# %%
valor = float(input(<252))
if valor< 0:
    #parte que executa com condição True
    print("o número que você digitou é negativo")
    print("e eu sei disso pois é menor que zero")
else:
    #parte que executa com condição False
    print("O número que você digitou é positivo")
    print("ou é igual a zero, não tenho certeza")
    print("Fim  do programa")
# Out:
#   Cell In[3], line 1
#     valor = float(input(<252))
#                         ^
# SyntaxError: invalid syntax

# %%
valor = float(input(<2))
if valor< 10:
    #parte que executa com condição True
    print("o número que você digitou é negativo")
    print("e eu sei disso pois é menor que zero")
else:
    #parte que executa com condição False
    print("O número que você digitou é positivo")
    print("ou é igual a zero, não tenho certeza")
    print("Fim  do programa")
# Out:
#   Cell In[4], line 1
#     valor = float(input(<2))
#                         ^
# SyntaxError: invalid syntax

# %%
valor = float(input(2))
if valor< 10:
    #parte que executa com condição True
    print("o número que você digitou é negativo")
    print("e eu sei disso pois é menor que zero")
else:
    #parte que executa com condição False
    print("O número que você digitou é positivo")
    print("ou é igual a zero, não tenho certeza")
    print("Fim  do programa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 valor = float(input(2))
#       2 if valor< 10:
#       3     #parte que executa com condição True
#       4     print("o número que você digitou é negativo")
#
# ValueError: could not convert string to float: ''

# %%
valor = float(input('Digite um número: '))
escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
if escolha == 1:
            dobro = 2 * valor
            print(f'O dobro de {valor} é {dobro}')
else:
            metade = valor / 2
            print(f'A metade de {valor} é {metade}')
print('Fim do programa')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 valor = float(input('Digite um número: '))
#       2 escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
#       3 if escolha == 1:
#
# ValueError: could not convert string to float: ''

# %%
valor = float(input('5'))
escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
if escolha == 1:
            dobro = 2 * valor
            print(f'O dobro de {valor} é {dobro}')
else:
            metade = valor / 2
            print(f'A metade de {valor} é {metade}')
print('Fim do programa')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 valor = float(input('5'))
#       2 escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
#       3 if escolha == 1:
#
# ValueError: could not convert string to float: ''

# %%
valor = float(input('5'))
escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
if escolha == 1:
            dobro = 2 * valor
            print(f'O dobro de {valor} é {dobro}')
else:
            metade = valor / 2
            print(f'A metade de {valor} é {metade}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 valor = float(input('5'))
#       2 escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
#       3 if escolha == 1:
#
# ValueError: could not convert string to float: ''

# %%
valor = float(input('5'))
escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
if escolha == 1:
            dobro = 2 * valor
            print(f'O dobro de {valor} é {dobro}')
else:
            metade = valor / 2
            print(f'A metade de {valor} é {metade}')
print('Fim do programa')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 valor = float(input('5'))
#       2 escolha = float(input('Digite 1 para calcular o dobro, ou outra coisa para calcular a metade:'))
#       3 if escolha == 1:
#
# ValueError: could not convert string to float: ''
