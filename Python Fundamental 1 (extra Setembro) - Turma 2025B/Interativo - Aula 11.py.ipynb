# %%
print("Bem vindo(a) ao meu programa que soma dois números")
valor1 = 147
valor2 = 253
soma = valor1 + valor2
print("O resultado da soma destes dois números é:", soma)
# Out:
# Bem vindo(a) ao meu programa que soma dois números
# O resultado da soma destes dois números é: 400

# %%
print("Bem vindo(a) ao meu programa que soma dois números")
valor1=147
valor2=253
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)
# Out:
# Bem vindo(a) ao meu programa que soma dois números
# O resultado da soma destes dois números é: 400

# %%
print("Bem vindo(a) ao meu programa que soma dois números")
valor1=147
valor2=253
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)

print("Bem Vindo(a) ao meu programa que soma dois números")
valor1=float(input('2653'))
valor2=float(input("2356"))
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)
# Out:
# Bem vindo(a) ao meu programa que soma dois números
# O resultado da soma destes dois números é: 400
# Bem Vindo(a) ao meu programa que soma dois números
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       5 print("O resultado da soma destes dois números é:", soma)
#       7 print("Bem Vindo(a) ao meu programa que soma dois números")
# ----> 8 valor1=float(input('2653'))
#       9 valor2=float(input("2356"))
#      10 soma=valor1+valor2
#
# ValueError: could not convert string to float: ''

# %%
print("Bem vindo(a) ao meu programa que soma dois números")
valor1=147
valor2=253
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)

print("Bem Vindo(a) ao meu programa que soma dois números")
valor1=float(input '2653')
valor2=float(input"2356")
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)
# Out:
#   Cell In[5], line 8
#     valor1=float(input '2653')
#                        ^
# SyntaxError: invalid syntax

# %%
print("Bem vindo(a) ao meu programa que soma dois números")
valor1=147
valor2=253
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)

print("Bem Vindo(a) ao meu programa que soma dois números")
valor1=float(input'2653')
valor2=float(input"2356")
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)
# Out:
#   Cell In[6], line 8
#     valor1=float(input'2653')
#                       ^
# SyntaxError: invalid syntax

# %%
print("Bem vindo(a) ao meu programa que soma dois números")
valor1=147
valor2=253
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)

print("Bem Vindo(a) ao meu programa que soma dois números")
valor1=2653
valor2=2356
soma=valor1+valor2
print("O resultado da soma destes dois números é:", soma)
# Out:
# Bem vindo(a) ao meu programa que soma dois números
# O resultado da soma destes dois números é: 400
# Bem Vindo(a) ao meu programa que soma dois números
# O resultado da soma destes dois números é: 5009
