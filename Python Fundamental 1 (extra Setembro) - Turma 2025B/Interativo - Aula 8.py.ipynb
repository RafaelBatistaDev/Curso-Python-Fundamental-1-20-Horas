# %%
lala="Yan"
print=(lala)

# %%
lala="Yan"
print=(lala)

# %%
#print=('lalala')

x="lalala"
print(x)

# %%
#print=('lalala')

x="lalala"
print(x)
resultado=5*20 #Efetuando a Multiplicação de dois valores

# %%
#print=('lalala')

x="lalala"
print(x)

resultado=5*20 #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
#print=('lalala')

x="lalala"
print(x)

resultado="5*20" #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
x="lalala"
print(x)

resultado="5*20" #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
x="lalala"
print(x)

resultado=("5*20") #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
resultado=("5*20") #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
resultado="5*20" #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
resultado=5*20 #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
resultado='5*20' #Efetuando a Multiplicação de dois valores
print(resultado)

# %%
resultado='5*20' #Efetuando a Multiplicação de dois valores
print("resultado")

# %%
resultado=('5*20') #Efetuando a Multiplicação de dois valores
print(resultado)
