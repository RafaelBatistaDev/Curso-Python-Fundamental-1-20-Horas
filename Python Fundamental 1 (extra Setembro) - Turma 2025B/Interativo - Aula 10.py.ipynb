# %%
print("Bem vindo(a) ao meu programa que soma dois números")
digitado1=input("147")
digitado2=input("253")
valor1=float(digitado1) #Transforma a string digitada em float
valor2=float(digitado2) #Transforma a string digitada em float
soma=(valor1+valor2) #Agora a soma é em valores numericos
print("O resultado da soma destes dois numeros é:", soma)
# Out:
# Bem vindo(a) ao meu programa que soma dois números
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       2 digitado1=input("147")
#       3 digitado2=input("253")
# ----> 4 valor1=float(digitado1) #Transforma a string digitada em float
#       5 valor2=float(digitado2) #Transforma a string digitada em float
#       6 soma=(valor1+valor2) #Agora a soma é em valores numericos
#
# ValueError: could not convert string to float: ''
